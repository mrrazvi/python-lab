# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../data/dubai-real-estate-rents-2025-12.csv', parse_dates=True)

# df = pd.DataFrame({
#     'Prices': ['10', '13', '11'],
#     'Unit': ['Studio', 'Flat', 'Studio']
# })

prices = pd.Series(['10', '13', '11', '5', '10.1', '50'], name="Prices")
# Out:
# /var/folders/v_/k17sgm3s57x4s_9qkffgpdhw0000gn/T/ipykernel_37190/1596775473.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../data/dubai-real-estate-rents-2025-12.csv', parse_dates=True)

# %%
df.head()
# Out:
#      REGISTRATION_DATE           START_DATE             END_DATE VERSION_EN  \
# 0  2025-12-01 00:02:13  2025-12-01 00:00:00  2026-11-30 00:00:00        New
# 1  2025-12-01 00:07:44  2025-12-01 00:00:00  2026-11-30 00:00:00        New
# 2  2025-12-01 00:09:40  2025-12-01 00:00:00  2026-11-30 00:00:00    Renewed
# 3  2025-12-01 00:13:04  2025-12-08 00:00:00  2026-12-07 00:00:00    Renewed
# 4  2025-12-01 00:30:26  2026-01-10 00:00:00  2027-01-09 00:00:00    Renewed
#
#                   AREA_EN  CONTRACT_AMOUNT  ANNUAL_AMOUNT IS_FREE_HOLD_EN  \
# 0   Al Barsha South Fifth          70000.0        70000.0       Free Hold
# 1             Marsa Dubai           5000.0         5000.0       Free Hold
# 2  Al Barshaa South Third          45000.0        45000.0       Free Hold
# 3       Muhaisanah Fourth          38036.0        38036.0   Non Free Hold
# 4              Nadd Hessa          36380.0        36380.0       Free Hold
#
# ...

# %%
prices
# Out:
# 0      10
# 1      13
# 2      11
# 3       5
# 4    10.1
# 5      50
# Name: Prices, dtype: object

# %%
type(df['ANNUAL_AMOUNT'])
# Out:
# pandas.core.series.Series

# %%
type(prices)
# Out:
# pandas.core.series.Series

# %%
df['ANNUAL_AMOUNT'].max()
# Out:
# np.float64(29181568.0)

# %%
df['ANNUAL_AMOUNT'].min()
# Out:
# np.float64(1.0)

# %%
df['ANNUAL_AMOUNT'].describe()
# Out:
# count    6.913700e+04
# mean     2.996450e+05
# std      8.744415e+05
# min      1.000000e+00
# 25%      4.600000e+04
# 50%      7.300000e+04
# 75%      1.500000e+05
# max      2.918157e+07
# Name: ANNUAL_AMOUNT, dtype: float64

# %%
df.head(1)
# Out:
#      REGISTRATION_DATE           START_DATE             END_DATE VERSION_EN  \
# 0  2025-12-01 00:02:13  2025-12-01 00:00:00  2026-11-30 00:00:00        New
#
#                  AREA_EN  CONTRACT_AMOUNT  ANNUAL_AMOUNT IS_FREE_HOLD_EN  \
# 0  Al Barsha South Fifth          70000.0        70000.0       Free Hold
#
#    ACTUAL_AREA PROP_TYPE_EN PROP_SUB_TYPE_EN  ROOMS     USAGE_EN  \
# 0        54.78         Unit             Flat    NaN  Residential
#
#    NEAREST_METRO_EN NEAREST_MALL_EN           NEAREST_LANDMARK_EN  PARKING  \
# 0  Damac Properties     Marina Mall  Sports City Swimming Academy      NaN
#
#    TOTAL_PROPERTIES MASTER_PROJECT_EN    PROJECT_EN
# 0                 1               NaN  CLOUD Tower

# %%
df.tail(1)
# Out:
#          REGISTRATION_DATE           START_DATE             END_DATE  \
# 69136  2025-12-23 23:44:28  2025-12-24 00:00:00  2026-12-23 00:00:00
#
#       VERSION_EN                     AREA_EN  CONTRACT_AMOUNT  ANNUAL_AMOUNT  \
# 69136    Renewed  Al Qusais Industrial Fifth          39500.0        39500.0
#
#       IS_FREE_HOLD_EN  ACTUAL_AREA PROP_TYPE_EN PROP_SUB_TYPE_EN  ROOMS  \
# 69136   Non Free Hold        73.77         Unit             Flat    NaN
#
#           USAGE_EN         NEAREST_METRO_EN     NEAREST_MALL_EN  \
# 69136  Residential  Al Qusais Metro Station  City Centre Mirdif
#
#                NEAREST_LANDMARK_EN  PARKING  TOTAL_PROPERTIES  \
# 69136  Dubai International Airport      NaN                 1
#
#       MASTER_PROJECT_EN PROJECT_EN
# 69136               NaN        NaN

# %%
df.dtypes
# Out:
# REGISTRATION_DATE       object
# START_DATE              object
# END_DATE                object
# VERSION_EN              object
# AREA_EN                 object
# CONTRACT_AMOUNT        float64
# ANNUAL_AMOUNT          float64
# IS_FREE_HOLD_EN         object
# ACTUAL_AREA            float64
# PROP_TYPE_EN            object
# PROP_SUB_TYPE_EN        object
# ROOMS                  float64
# USAGE_EN                object
# NEAREST_METRO_EN        object
# NEAREST_MALL_EN         object
# NEAREST_LANDMARK_EN     object
# PARKING                float64
# TOTAL_PROPERTIES         int64
# MASTER_PROJECT_EN       object
# PROJECT_EN              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69137 entries, 0 to 69136
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   REGISTRATION_DATE    69137 non-null  object
#  1   START_DATE           69137 non-null  object
#  2   END_DATE             69137 non-null  object
#  3   VERSION_EN           69137 non-null  object
#  4   AREA_EN              69137 non-null  object
#  5   CONTRACT_AMOUNT      69137 non-null  float64
#  6   ANNUAL_AMOUNT        69137 non-null  float64
#  7   IS_FREE_HOLD_EN      69137 non-null  object
#  8   ACTUAL_AREA          69137 non-null  float64
#  9   PROP_TYPE_EN         69137 non-null  object
#  10  PROP_SUB_TYPE_EN     68875 non-null  object
#  11  ROOMS                2246 non-null   float64
#  12  USAGE_EN             68840 non-null  object
#  13  NEAREST_METRO_EN     58240 non-null  object
#  14  NEAREST_MALL_EN      57026 non-null  object
# ...

# %%
df['ANNUAL_AMOUNT'].shape
# Out:
# (69137,)

# %%
date_prices_type_rooms = df[['REGISTRATION_DATE', 'ANNUAL_AMOUNT', 'PROP_SUB_TYPE_EN', 'ROOMS']]
studios = df.loc[df['PROP_SUB_TYPE_EN'] == 'Flat', ['REGISTRATION_DATE', 'ANNUAL_AMOUNT']]
studios.head()
# Out:
#      REGISTRATION_DATE  ANNUAL_AMOUNT
# 0  2025-12-01 00:02:13        70000.0
# 1  2025-12-01 00:07:44         5000.0
# 3  2025-12-01 00:13:04        38036.0
# 4  2025-12-01 00:30:26        36380.0
# 5  2025-12-01 00:43:09        70000.0

# %%
date_prices_type_rooms.shape
# Out:
# (69137, 4)

# %%
flats = df[df['PROP_SUB_TYPE_EN'] == 'Flat']
parking = df[df['PARKING'] == 1]

# %%
flats.shape
# Out:
# (43200, 20)

# %%
flats.head(2)
# Out:
#      REGISTRATION_DATE           START_DATE             END_DATE VERSION_EN  \
# 0  2025-12-01 00:02:13  2025-12-01 00:00:00  2026-11-30 00:00:00        New
# 1  2025-12-01 00:07:44  2025-12-01 00:00:00  2026-11-30 00:00:00        New
#
#                  AREA_EN  CONTRACT_AMOUNT  ANNUAL_AMOUNT IS_FREE_HOLD_EN  \
# 0  Al Barsha South Fifth          70000.0        70000.0       Free Hold
# 1            Marsa Dubai           5000.0         5000.0       Free Hold
#
#    ACTUAL_AREA PROP_TYPE_EN PROP_SUB_TYPE_EN  ROOMS     USAGE_EN  \
# 0        54.78         Unit             Flat    NaN  Residential
# 1        38.83         Unit             Flat    NaN  Residential
#
#         NEAREST_METRO_EN NEAREST_MALL_EN           NEAREST_LANDMARK_EN  \
# 0       Damac Properties     Marina Mall  Sports City Swimming Academy
# 1  Jumeirah Lakes Towers     Marina Mall  Sports City Swimming Academy
#
#    PARKING  TOTAL_PROPERTIES MASTER_PROJECT_EN    PROJECT_EN
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(x='REGISTRATION_DATE', y='ANNUAL_AMOUNT')
# Out:
# <Axes: xlabel='REGISTRATION_DATE'>

# %%
df['PROP_SUB_TYPE_EN'].value_counts()
# Out:
# PROP_SUB_TYPE_EN
# Flat                              43200
# Office                             8799
# Labor Camps                        5744
# Shop                               4912
# Villa                              3557
# Warehouse                           686
# Studio                              596
# Hotel                               462
# Complex Villas                      265
# Showroom                            203
# Hotel apartments                     82
# Restaurant                           43
# Staff Accommodation                  41
# Kiosk                                32
# Workshop                             32
# Clinic                               27
# Warehouse complex                    22
# Parking                              20
# Building                             16
# Mezzanine                            16
# Complex Warehouse                    15
# Arabian House                        14
# Store                                12
# ...

# %%
df.sort_values(by='REGISTRATION_DATE', ascending=False)
# Out:
#          REGISTRATION_DATE           START_DATE             END_DATE  \
# 69136  2025-12-23 23:44:28  2025-12-24 00:00:00  2026-12-23 00:00:00
# 69135  2025-12-23 23:39:24  2026-01-14 00:00:00  2026-10-13 00:00:00
# 69134  2025-12-23 23:16:16  2025-12-28 00:00:00  2026-12-27 00:00:00
# 69133  2025-12-23 23:13:29  2026-01-01 00:00:00  2026-12-31 00:00:00
# 69132  2025-12-23 23:11:48  2025-12-26 00:00:00  2026-12-25 00:00:00
# ...                    ...                  ...                  ...
# 4      2025-12-01 00:30:26  2026-01-10 00:00:00  2027-01-09 00:00:00
# 3      2025-12-01 00:13:04  2025-12-08 00:00:00  2026-12-07 00:00:00
# 2      2025-12-01 00:09:40  2025-12-01 00:00:00  2026-11-30 00:00:00
# 1      2025-12-01 00:07:44  2025-12-01 00:00:00  2026-11-30 00:00:00
# 0      2025-12-01 00:02:13  2025-12-01 00:00:00  2026-11-30 00:00:00
#
#       VERSION_EN                     AREA_EN  CONTRACT_AMOUNT  ANNUAL_AMOUNT  \
# ...

# %%
df['REGISTRATION_DATE'] = pd.to_datetime(df['REGISTRATION_DATE'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69137 entries, 0 to 69136
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   REGISTRATION_DATE    69137 non-null  datetime64[ns]
#  1   START_DATE           69137 non-null  object
#  2   END_DATE             69137 non-null  object
#  3   VERSION_EN           69137 non-null  object
#  4   AREA_EN              69137 non-null  object
#  5   CONTRACT_AMOUNT      69137 non-null  float64
#  6   ANNUAL_AMOUNT        69137 non-null  float64
#  7   IS_FREE_HOLD_EN      69137 non-null  object
#  8   ACTUAL_AREA          69137 non-null  float64
#  9   PROP_TYPE_EN         69137 non-null  object
#  10  PROP_SUB_TYPE_EN     68875 non-null  object
#  11  ROOMS                2246 non-null   float64
#  12  USAGE_EN             68840 non-null  object
#  13  NEAREST_METRO_EN     58240 non-null  object
#  14  NEAREST_MALL_EN      57026 non-null  object
# ...

# %%
df.plot(x='REGISTRATION_DATE', y='ANNUAL_AMOUNT')
# Out:
# <Axes: xlabel='REGISTRATION_DATE'>
